# %%
import wbgapi as wb
import pandas as pd
# Pull China GDP data from World Bank
df = wb.data.DataFrame('NY.GDP.MKTP.CD', 'CHN')
print(df.head(10))
# Out:
#                YR1960        YR1961        YR1962        YR1963        YR1964  \
# economy
# CHN      5.984624e+10  5.016230e+10  4.731074e+10  5.081223e+10  5.982186e+10
#
#                YR1965        YR1966        YR1967        YR1968        YR1969  \
# economy
# CHN      7.056599e+10  7.685405e+10  7.301135e+10  7.098032e+10  7.984779e+10
#
#          ...        YR2016        YR2017        YR2018        YR2019  \
# economy  ...
# CHN      ...  1.145602e+13  1.253756e+13  1.414777e+13  1.456017e+13
#
#                YR2020        YR2021        YR2022        YR2023        YR2024  \
# economy
# CHN      1.499641e+13  1.820170e+13  1.831677e+13  1.827036e+13  1.874380e+13
#
#          YR2025
# economy
# CHN         NaN
#
# [1 rows x 66 columns]
